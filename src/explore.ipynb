# %% [markdown]
# # Explore here
#
# It's recommended to use this notebook for exploration purposes.
#
# For example:
#
# 1. You could import the CSV generated by python into your notebook and explore it.
# 2. You could connect to your database using `pandas.read_sql` from this notebook and explore it.

# %%
# # Example reading the SQL database from here



import sqlite3
import pandas as pd

con = sqlite3.connect("/workspaces/web-scraping-project-tutorial/nomegustaelfutbol.db")
df = pd.read_sql_query("SELECT * FROM futbol_tabla", con)


con.close()


# from app2 import df
columns_drop = ['PJ', 'PG', 'PE', 'PP', 'GF', 'GC', 'DIF']
df.drop(columns = columns_drop, axis=1, inplace=True)
print(df)
# df['Club'] = df['Club'].str.replace('\n','')
#df
# Out:
#     Pos                        Club  PTS
# 0     1            *   Cobresal CSL   46
# 1     2              Huachipato HUA   39
# 2     3                Colo-Colo CC   35
# 3     4               Palestino PAL   35
# 4     5                 Everton EVE   35
# 5     6         Unión La Calera ULC   32
# 6     7      *   Coquimbo Unido COQ   32
# 7     8           Unión Española UE   31
# 8     9     Universidad Católica UC   31
# 9    10    Universidad de Chile UCH   31
# 10   11               O´Higgins OHI   27
# 11   12                Ñublense ÑUB   27
# 12   13           Audax Italiano AI   26
# 13   14              Magallanes MAG   22
# 14   15        Deportes Copiapó CDC   22
# 15   16            Curicó Unido CUR   21

# %% [markdown]
# ### 10 Gráfica

# %%
import matplotlib.pyplot as plt
plt.plot(df['Club'], df['PTS'])
plt.xlabel('Clubes')
plt.xticks(rotation=90)  
plt.show()

# %%
# import os

# Print the current working directory
# print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /workspaces/web-scraping-project-tutorial/src

# %%
# from dotenv import load_dotenv

# from sqlalchemy import create_engine
# import pandas as pd

# # load the .env file variables
# load_dotenv()

# connection_string = f"mysql+pymysql://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}@{os.getenv('DB_HOST')}/{os.getenv('DB_NAME')}?autocommit=true"
# engine = create_engine(connection_string)
# engine.connect()

# dataframe = pd.read_sql("Select * from books;", engine)
# print(dataframe.describe())
# Example importing the CSV here

# dataframe = pd.read_csv('../path/to/file.csv')
# dataframe.describe()
